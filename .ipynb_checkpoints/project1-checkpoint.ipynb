# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import libraries
from implementation import *
from helpers import *
from cross_validation import *
from proj_helpers import *

# %%
# set random seed
np.random.seed(10)

# %%
# Load training data
DATA_TRAIN_PATH = 'data/train.csv'
y_data, tX_data, ids = load_csv_data(DATA_TRAIN_PATH)
# Load test data
DATA_TEST_PATH = 'data/test.csv'
_ , tX_test_data, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
# define models
models = ['gd',
          'sgd',
          'least squares',
          'ridge regression',
          'logistic regression',
          'regularized logistic regression']

# select model
selected_model = 'ridge regression'

#define parameters
poly_degrees = [15] #[17, 18, 19, 20, 21]
inv_log_degrees = [10] #[13, 14, 15, 16, 17]
gammas = [1]
lambdas = np.logspace(-15, -1, 30)
max_iters = [10]

# %%
# define cross validation parameters
ratio = 0.5 # ratio of complete data to use (for testing purpose - much faster)
k_fold = 4 # number of folds to use for the cross validation
# -------------------------------------

tX = tX_data[:int(ratio * tX_data.shape[0])]
y = y_data[:int(ratio * y_data.shape[0])]

# training
mask = get_categorical_masks(tX)

print('Training with {}'.format(selected_model))
for idx in mask:
    print('Preprocessing mask {}'.format(idx))
    
    xtrain = tX[mask[idx]]
    ytrain = y[mask[idx]]
    
    grid_results = cross_validation_demo(ytrain, xtrain, selected_model, poly_degrees, inv_log_degrees, max_iters, gammas, lambdas, k_fold)
    print(f'Best parameters for mask {idx}:')
    print(grid_results[find_best_parameters(grid_results, min_=False)[1]], sep='\n')
    
    # visualization of accuracy
    if len(poly_degrees) == 1 and len(inv_log_degrees) == 1 and len(gammas) == 1 and len(lambdas) > 1:
        accuracy_visualization_1(lambdas, [d['acc_mean'] for d in grid_results], param1='lambda', title=f'Accuracy plot of mask {idx} for lambda')
    
    if len(poly_degrees) == 1 and len(inv_log_degrees) == 1 and len(lambdas) == 1 and len(gammas) > 1:
        accuracy_visualization_1(gammas, [d['acc_mean'] for d in grid_results], param1='gamma', title=f'Accuracy plot of mask {idx} for gamma')
    
    if len(lambdas) == 1 and len(gammas) == 1 and len(poly_degrees) > 2 and len(inv_log_degrees) > 2:
        A = np.zeros((len(poly_degrees), len(inv_log_degrees)))
        poly_dict = dict(zip(poly_degrees, list(range(0,len(poly_degrees)))))
        log_dict = dict(zip(inv_log_degrees, list(range(0,len(inv_log_degrees)))))
        for d in grid_results:
            A[poly_dict[d['poly_degree']], log_dict[d['log_degree']]] = d['acc_mean']
        accuracy_visualization_2(poly_degrees, inv_log_degrees, A, name1='poly_degrees', name2='inv_log_degrees', title=f'Accuracy Visualization of mask {idx}')
    #-----------------------------------------------------------------------------------

    print('---------------------------------------------------------------------------------')
# Out:
# Training with ridge regression
# Preprocessing mask 0
# Best parameters for mask 0:
# {'poly_degree': 15, 'log_degree': 10, 'max_iteration': 10, 'gamma': 1, 'lambda': 7.278953843983161e-12, 'acc_mean': 0.7660825732117138, 'acc_std': 0.002105948501880587}
# ---------------------------------------------------------------------------------
# Preprocessing mask 1
# Best parameters for mask 1:
# {'poly_degree': 15, 'log_degree': 10, 'max_iteration': 10, 'gamma': 1, 'lambda': 9.236708571873847e-15, 'acc_mean': 0.7668232015687894, 'acc_std': 0.00631285452428599}
# ---------------------------------------------------------------------------------
# Preprocessing mask 2
# Best parameters for mask 2:
# {'poly_degree': 15, 'log_degree': 10, 'max_iteration': 10, 'gamma': 1, 'lambda': 2.8072162039411815e-14, 'acc_mean': 0.8322316024211531, 'acc_std': 0.006559210943574445}
# ---------------------------------------------------------------------------------
# Preprocessing mask 3
# Best parameters for mask 3:
# {'poly_degree': 15, 'log_degree': 10, 'max_iteration': 10, 'gamma': 1, 'lambda': 9.236708571873847e-15, 'acc_mean': 0.7553879310344828, 'acc_std': 0.003079459087550659}
# ---------------------------------------------------------------------------------
